# %%
import random
from datetime import timedelta
import numpy as np
import pandas as pd
from faker import Faker
fake = Faker()

random.seed(42)
np.random.seed(42)
subscriptions = pd.read_parquet("../Datasources/subscriptions.parquet")
subscriptions.head()
# Out:
#   subscription_id      user_id plan_name  subscription_price currency  \
# 0     SUB00000001  USR00987232  Standard              499.00      INR
# 1     SUB00000002  USR00079955     Basic              199.00      INR
# 2     SUB00000003  USR00567131     Basic                6.99      GBP
# 3     SUB00000004  USR00500892     Basic            10692.00      JPY
# 4     SUB00000005  USR00055400  Standard              499.00      INR
#
#   billing_cycle                 start_date   end_date  auto_renew  \
# 0       Monthly 2024-08-04 12:12:45.467629 2025-07-15       False
# 1       Monthly 2021-11-07 06:01:01.254655 2024-12-01       False
# 2       Monthly 2021-06-30 06:34:21.511004        NaT        True
# 3        Annual 2020-03-17 01:42:30.914608 2020-05-08       False
# 4       Monthly 2022-12-23 17:09:05.878159        NaT       False
#
#   subscription_status
# 0           CANCELLED
# 1           CANCELLED
# 2              ACTIVE
# 3           CANCELLED
# 4              ACTIVE

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 56
#      52             "amount": amount,
#      53
#      54             "currency": row["currency"],
#      55
# ---> 56             "payment_method": random.choices(
#      57                 PAYMENT_METHODS,
#      58                 weights=PAYMENT_METHOD_WEIGHTS,
#      59                 k=1
#
# File /opt/homebrew/Cellar/python@3.11/3.11.15/Frameworks/Python.framework/Versions/3.11/lib/python3.11/random.py:495, in Random.choices(self, population, weights, cum_weights, k)
#     493     return [population[floor(random() * n)] for i in _repeat(None, k)]
#     494 try:
# --> 495     cum_weights = list(_accumulate(weights))
#     496 except TypeError:
#     497     if not isinstance(weights, int):
#
# KeyboardInterrupt:
